# %%
# multiple element API request - PRZYDA SIĘ
"""
track_endpoint = "https://api.spotify.com/v1/tracks/"

tracks_ids_endpoints = track_ids
track_responses = []

for endpoint in tracks_ids_endpoints:
    #print(f"{track_endpoint}{endpoint}")
    track_responses.append(requests.get(f"{track_endpoint}{endpoint}", headers={"Authorization": "Bearer BQCXgiCqKDEzZzQLMW8fEOOWD1cILc5-SCW1eQtugJbhronPzbZqsj-qIXVssfAhSQkYHD3lTCWJPfY3n2kKZBdVv8ovFCr7_cfDMEVnfwLkGCirvmqYVEuZ7Hsjy93B60c3e6A6x4bP01nCz90Wkbyr3dKdYksS6MYRNf7bsh1EzsdG"}))"""
# Out:
# '\ntrack_endpoint = "https://api.spotify.com/v1/tracks/"\n\ntracks_ids_endpoints = track_ids\ntrack_responses = []\n\nfor endpoint in tracks_ids_endpoints:\n    #print(f"{track_endpoint}{endpoint}")\n    track_responses.append(requests.get(f"{track_endpoint}{endpoint}", headers={"Authorization": "Bearer BQCXgiCqKDEzZzQLMW8fEOOWD1cILc5-SCW1eQtugJbhronPzbZqsj-qIXVssfAhSQkYHD3lTCWJPfY3n2kKZBdVv8ovFCr7_cfDMEVnfwLkGCirvmqYVEuZ7Hsjy93B60c3e6A6x4bP01nCz90Wkbyr3dKdYksS6MYRNf7bsh1EzsdG"}))'

# %% [markdown]
# ### Libraries import

# %%
import json
import time
from IPython.display import JSON
import requests
import pandas as pd
import numpy as np

# Data viz packages
import seaborn as sns
from matplotlib import pyplot as plt

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# details saved in variables

client_id = '53da43c72c1c4cd3b16120db1ef96e99'
secret = 'ee7cd2be7a75420dad6b9b6e63d20a31'
user_id = 'hfe8l7rf76dr701yyrdpqwzih'
token = "Bearer BQCKhxFgNt988fjkKMTX1lq41kA7aSjzeRdoJaTshzIM8pp_i37IiQziGJ1WhsiD5H1yNT2uEydyDcpkqNKEzFUl7_DylhfuELHW_AjkC7I0RVLu7ZRqIAhoPJtevqFXPxwhFTybAG4EWA4u7Lwc2hbtfBjoSnj5kgnsCgF24oZxksK5"

# %%
# API requests

user_response = requests.get("https://api.spotify.com/v1/users/hfe8l7rf76dr701yyrdpqwzih/", headers={"Authorization": token})
playlist_response = requests.get("https://api.spotify.com/v1/users/hfe8l7rf76dr701yyrdpqwzih/playlists", headers={"Authorization": token})
playlists_response = requests.get("https://api.spotify.com/v1/playlists/7nmyEj4Fhw7i1ZUejh0cB2/tracks", headers={"Authorization": "Bearer BQBEZSUnpeBrPFSFmr1hGp0WwGPGhigv6E9AjKFM_pVSns9P845YKQ-DjVHdK2TDYsLbR9hVNa0rH-rZAZJAxsUotrwrofiVEKeGzqTCLAETCmLJp4LfUXtt42q1g92abSjBbj4IFBTdgkbFww6UDzkWPfJ87Nysa4_6bZIukbgCRMWe"})

# %%
# connection to Spotify

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# function to get user playlists id

def get_playlists_id(user_id):
    playlists_id_list = []
    
    user_playlists = sp.user_playlists(user_id)
    
    for item in user_playlists['items']:
        data = item['id']
        playlists_id_list.append(data)
    
    return playlists_id_list

# %%
playlists_id = get_playlists_id(user_id)
len(playlists_id)
# Out:
# 6

# %%
# function to get tracks details from user playlists

def get_playlist_tracks_details(playlists_id):
    track_details_list = []
    
    for playlist in playlists_id:
        playlist_tracks = sp.playlist_tracks(playlist, fields=None, limit=100, offset=0, market=None, additional_types=('track', ))
    
        for item in playlist_tracks['items']:
            data = {'id_track': item['track']['id'], 'title': item['track']['name'], 'artist': item['track']['artists'][0]['name'],'artist_id': item['track']['artists'][0]['id'], 'duration_in_sec': round((item['track']['duration_ms']*0.001),2)
        }
            track_details_list.append(data)
        
    return (pd.DataFrame(track_details_list))

# %%
# save tracks details in dataframe
track_details_df = get_playlist_tracks_details(playlists_id)

# %%
display(track_details_df)
# Out:
#                    id_track                                             title  \
# 0    5HkTQIVUT0dmjSpUIpZpKw                             Rób To, W Co Wierzysz
# 1    1DIXPcTDzTj8ZMHt3PDt8p                                Gangsta's Paradise
# 2    1eyzqe2QqGZUmfcPZtrIyt                                     Midnight City
# 3    0uTw7TNnYn64XmCAo5jr0c                                         The Pines
# 4    45AEyRmM8KB4nNHw3L8PCY  Drinks - From "Promising Young Woman" Soundtrack
# ..                      ...                                               ...
# 507  6APC1Q8zadBJD0nP2KjA3z                          Bécane - live acoustique
# 508  3t35L0LVjdCXcYsjJgAFkZ                                     4 Page Letter
# 509  72znJoM6pqIyL423urSTRR                                              Love
# 510  1AMJtqWM66CsQM4L2nQhxc                                      Kawa i Xanax
# 511  1ZeBRaUlfmys5RYScBsBfQ                                            Bogini
#
#           artist               artist_id  duration_in_sec
# 0          Sokół  5Kuxl5ZenCl9fYzmtin6ot           258.15
# 1         Coolio  3y24n3XhZ96wgwRXjvS17T           240.69
# 2            M83  63MQldklfxkjYDoUE4Tppz           241.44
# 3      070 Shake  12Zk1DFhCbHY6v3xep2ZjI           213.61
# 4            Cyn  0lPhSdyfILTWuDUWJRyAk7           149.86
# ..           ...                     ...              ...
# 507      Lomepal  1Yfe3ONJlioHys7jwHdfVm           308.88
# 508      Aaliyah  0urTpYCsixqZwgNTkPJOJ4           292.35
# 509  Quebonafide  1fxbULcd6ryMNc1usHoP0R           184.71
# 510  Quebonafide  1fxbULcd6ryMNc1usHoP0R           249.15
# 511  Quebonafide  1fxbULcd6ryMNc1usHoP0R           262.15
#
# [512 rows x 5 columns]

# %% [markdown]
# ### Data pre-processing

# %%
track_details_df.isnull().any()
# Out:
# id_track           False
# title              False
# artist             False
# artist_id          False
# duration_in_sec    False
# dtype: bool

# %%
track_details_df.dtypes
# Out:
# id_track            object
# title               object
# artist              object
# artist_id           object
# duration_in_sec    float64
# dtype: object

# %%
print("Number of unique artists: ", track_details_df.artist.nunique())
print("Longest track duration in sec: ", track_details_df.duration_in_sec.max())
print("Shortest track duration in sec: ", track_details_df.duration_in_sec.min())
# Out:
# Number of unique artists:  257
# Longest track duration in sec:  670.15
# Shortest track duration in sec:  66.13

# %% [markdown]
# ### EDA

# %% [markdown]
# ideas:
#     artyści - top
#     arrtyści - bottom
#     czas dystrybucja
#     title words top (wordcloud?)

# %%
# data series

artist_count = track_details_df['artist'].value_counts()
artist_count = artist_count.sort_values(ascending=False)

artist_count_dictionary = artist_count.to_dict()

# %%
display(artist_count_dictionary)
# Out:
# {'Włodi': 26,
#  'Sokół': 23,
#  'Rasmentalism': 12,
#  'Pezet': 12,
#  'Nosowska': 12,
#  'Black Eyed Peas': 11,
#  'BANKS': 10,
#  'Quebonafide': 8,
#  'Coma': 8,
#  'Labrinth': 7,
#  'Nouvelle Vague': 7,
#  'Sonbird': 7,
#  'Daft Punk': 6,
#  'Beyoncé': 6,
#  'Adele': 6,
#  'Aaliyah': 6,
#  'AWOLNATION': 4,
#  'The Libertines': 4,
#  'Babyshambles': 4,
#  'Garbage': 4,
#  'schafter': 4,
#  'Daughter': 4,
#  'Rihanna': 4,
#  'O.S.T.R.': 4,
#  'Portishead': 3,
#  'Kavinsky': 3,
#  'Margaret': 3,
#  'Barbara Pravi': 3,
#  'Moby': 3,
#  'FKA twigs': 3,
#  'College & Electric Youth': 3,
#  'Whitney Houston': 3,
#  'M83': 3,
#  'Sade': 3,
#  'Coals': 3,
#  'The Chemical Brothers': 3,
#  'The Smashing Pumpkins': 3,
#  'KLP': 2,
#  'Bajm': 2,
#  'James Newton Howard': 2,
#  'Ludovico Einaudi': 2,
#  'Duncan Laurence': 2,
#  'Randy Newman': 2,
#  'Jakub Skorupa': 2,
#  'Czesław Niemen': 2,
#  'Toby Keith': 2,
#  'Peppino Gagliardi': 2,
#  'Dr. Dre': 2,
#  'Calvin Harris': 2,
#  'Lorde': 2,
#  'Justin Bieber': 2,
#  'ZHU': 2,
#  'Dag Savage': 2,
#  'Enzo Siffredi': 2,
#  'Maëlle': 2,
#  'Enzo Gragnianiello': 2,
#  '070 Shake': 2,
#  "Sinéad O'Connor": 2,
#  'Busty and the Bass': 2,
#  'Cyn': 2,
#  'The xx': 2,
#  'Dire Straits': 2,
#  'Manchester Orchestra': 2,
#  'Flirtini': 2,
#  'Kendrick Lamar': 2,
#  'PJ Harvey': 2,
#  'Tove Lo': 2,
#  'Sam Smith': 2,
#  'Daria Zawiałow': 2,
#  'Cleo Sol': 2,
#  'Daiana Lou': 2,
#  'Tash Sultana': 2,
#  'The Irrepressibles': 2,
#  'Krystyna Janda': 2,
#  'Alicia Keys': 2,
#  'Lilly Hates Roses': 2,
#  'Zbigniew Wodecki': 2,
#  'Camila Cabello': 2,
#  'Johnny Cash': 2,
#  'Diddy - Dirty Money': 2,
#  'Gaia': 2,
#  'Damian Lazarus': 2,
#  'Catherine Zeta-Jones': 2,
#  'Mata': 2,
#  'Hozier': 2,
#  'Florence + The Machine': 2,
#  'Bitamina': 2,
#  'Bobby Raps': 2,
#  'Lomepal': 2,
#  'Albo Inaczej': 2,
#  'Dwa Sławy': 2,
#  'No Doubt': 1,
#  'Mr. Big': 1,
#  'Phil Collins': 1,
#  'Patrick Swayze': 1,
#  'Tears For Fears': 1,
#  'BROODS': 1,
#  'Martyna Jakubowicz': 1,
#  'Outkast': 1,
#  'NAV': 1,
#  'SMOLIK / KEV FOX': 1,
#  'Groundfold': 1,
#  'Jesse McCartney': 1,
#  'Dido': 1,
#  'Magda Umer': 1,
#  'Kayah': 1,
#  'Jacob Banks': 1,
#  'Dj Black Belt Greg': 1,
#  'Amy Winehouse': 1,
#  'Jihae': 1,
#  'Vluestar': 1,
#  'Miss Kittin': 1,
#  'Małpa': 1,
#  'Paramore': 1,
#  'Natalia Kukulska': 1,
#  'Celeste': 1,
#  'Kaśka Sochacka': 1,
#  'Michael Nyman': 1,
#  'Rosalie.': 1,
#  'Kamil Holden Kryszak': 1,
#  'The Cure': 1,
#  'Nova': 1,
#  'Jacob Lee': 1,
#  'Linkin Park': 1,
#  'Pyotr Ilyich Tchaikovsky': 1,
#  'Cecilia Krull': 1,
#  'The Blue Nile': 1,
#  'Bitter:Sweet': 1,
#  'Marilyn Manson': 1,
#  'Sam Brown': 1,
#  'Melody Gardot': 1,
#  'Ornella Vanoni': 1,
#  'Nicholas Britell': 1,
#  'Jackson Greenberg': 1,
#  'Apparat': 1,
#  'Coolio': 1,
#  'Villagers': 1,
#  'Tony Renis': 1,
#  'Andrea Bocelli': 1,
#  'Erik Satie': 1,
#  'Jędrek Wołodko & Fantom': 1,
#  'Lenka Filipova': 1,
#  'Thom Yorke': 1,
#  'Deep Purple': 1,
#  'Nothing But Thieves': 1,
#  'Foals': 1,
#  '2raumwohnung': 1,
#  'Vincent & The Barbers': 1,
#  'Gidge': 1,
#  'Nostalghia': 1,
#  'David Lanz': 1,
#  'Pink Floyd': 1,
#  'Tim Berg': 1,
#  'LTJ X-Perience': 1,
#  'Adi Nowak': 1,
#  'Lizzo': 1,
#  'Louis Armstrong': 1,
#  'Zen Boutique': 1,
#  'Jorja Smith': 1,
#  'Arca': 1,
#  'Darius': 1,
#  'GINEVRA': 1,
#  'Neoni': 1,
#  'Phanee de Pool': 1,
#  'Vulfpeck': 1,
#  'Johann Strauss II': 1,
#  'LP': 1,
#  'Muchy': 1,
#  'Ella Fitzgerald': 1,
#  'Fismoll': 1,
#  'Silent Child': 1,
#  'Kyle Dixon & Michael Stein': 1,
#  'Kate Nash': 1,
#  'Marika': 1,
#  'Maciej Musiałowski': 1,
#  'ABRA': 1,
#  'Ji Mac': 1,
#  'Billie Eilish': 1,
#  'Julien Doré': 1,
#  'Rampue': 1,
#  'Telepathic Teddy Bear': 1,
#  'Camille Saint-Saëns': 1,
#  'Mansionair': 1,
#  'Ellie Goulding': 1,
#  'Coldplay': 1,
#  'Tom Waits': 1,
#  'Christophe Le Friant': 1,
#  'Ariana Grande': 1,
#  'Sia': 1,
#  'Björk': 1,
#  'Elisa': 1,
#  'The Verve': 1,
#  'Meek, Oh Why?': 1,
#  'Zuza Jabłońska': 1,
#  'JAY-Z': 1,
#  'Sorry Boys': 1,
#  'Fisz Emade Tworzywo': 1,
#  'The Swinging Suits': 1,
#  'Steph Copeland': 1,
#  'Surfaces': 1,
#  'Rebeka': 1,
#  'Videoclub': 1,
#  'Citizen Cope': 1,
#  'Kamil Pivot': 1,
#  'Fokus': 1,
#  'Julia Marcell': 1,
#  'WWO': 1,
#  'Mery Spolsky': 1,
#  'Ed Sheeran': 1,
#  'Foster The People': 1,
#  'Young Leosia': 1,
#  'Kelsey Lu': 1,
#  'Łona I Webber': 1,
#  'Rezerwat': 1,
#  'Gotan Project': 1,
#  'Kortez': 1,
#  'Eurythmics': 1,
#  'Miuosh': 1,
#  'Ten Typ Mes': 1,
#  'Essex': 1,
#  'Kasia Lins': 1,
#  'Sarius': 1,
#  'Dillon': 1,
#  'Lordofon': 1,
#  'Citipointe Worship': 1,
#  'Męskie Granie Orkiestra 2017': 1,
#  'Kora': 1,
#  'Sufjan Stevens': 1,
#  'zalagasper': 1,
#  'TENDER': 1,
#  'SYML': 1,
#  'Colapesce': 1,
#  'Electric Light Orchestra': 1,
#  'Swietliki': 1,
#  'Michael Kiwanuka': 1,
#  'Taco Hemingway': 1,
#  'Grzegorz Turnau': 1,
#  'Gang of Youths': 1,
#  'Nek': 1,
#  'Two Feet': 1,
#  'Pidżama Porno': 1,
#  'Ex:Re': 1,
#  'Leszek Możdżer': 1,
#  'Jeff Buckley': 1,
#  'Dawid Podsiadło': 1,
#  'Yndi': 1,
#  'The Weeknd': 1,
#  'Rothwell': 1,
#  'Christina Perri': 1,
#  'Platon Karataev': 1,
#  'Tallisker': 1,
#  'Askjell': 1,
#  'NOVY YA': 1,
#  'Natalia Oreiro': 1,
#  'Mariah Carey': 1,
#  'Ursine Vulpine': 1,
#  'Kathia': 1}
